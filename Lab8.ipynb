# %% [markdown]
# <a href="https://colab.research.google.com/github/ojohnso3-oss/ojohnso3-INST414/blob/main/Lab8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import shutil
import os

source_file = '/imdb_movies_2000to2022.actorXgenre (1).csv'
destination_dir = '/content/sample_data'

# Ensure the destination directory exists
os.makedirs(destination_dir, exist_ok=True)

# Construct the full destination path
destination_file = os.path.join(destination_dir, os.path.basename(source_file))

# Move the file
shutil.move(source_file, destination_file)

print(f"File '{source_file}' moved to '{destination_file}'")
# Out:
# File '/imdb_movies_2000to2022.actorXgenre (1).csv' moved to '/content/sample_data/imdb_movies_2000to2022.actorXgenre (1).csv'
