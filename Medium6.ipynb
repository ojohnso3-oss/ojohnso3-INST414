# %% [markdown]
# <a href="https://colab.research.google.com/github/ojohnso3-oss/ojohnso3-INST414/blob/main/Medium6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Scrape FlixPatrol top-10 for a given platform/country/date
def scrape_chart(platform, country, date_str):
    url = f"https://flixpatrol.com/top10/{platform}/{country}/{date_str}/"
    resp = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
    soup = BeautifulSoup(resp.text, "html.parser")
    rows = soup.select("table.table-striped tbody tr")
    return [{
        "rank": int(r.select_one(".rank").text),
        "title": r.select_one(".title a").text.strip(),
        "platform": platform,
        "country": country,
        "date": date_str,
    } for r in rows]
